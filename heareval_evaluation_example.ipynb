# %% [markdown]
# # HEAR 2021 Evaluation Example
#
# This notebook provides an example of downloading a pre-processed task and running evaluation using the Wav2Vec2 baseline model.

# %% [markdown]
# ## 1. Install Dependecies
# **Note: You may have to restart runtime after installation**

# %%
# !pip install heareval
# !pip install hearbaseline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting heareval
#   Downloading heareval-2021.1.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from heareval) (1.3.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from heareval) (6.1.2)
# Collecting pynvml
#   Downloading pynvml-11.4.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.5 MB/s
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from heareval) (0.10.3.post1)
# Requirement already satisfied: tensorflow>=2.0 in /usr/local/lib/python3.7/dist-packages (from heareval) (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from heareval) (1.0.2)
# Collecting torchinfo
#   Downloading torchinfo-1.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from heareval) (8.13.0)
# Collecting numpy==1.19.2
#   Downloading numpy-1.19.2-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 18.6 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from heareval) (1.11.0+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from heareval) (4.64.0)
# Collecting numba==0.48
#   Downloading numba-0.48.0-1-cp37-cp37m-manylinux2014_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 50.6 MB/s
# Collecting sed-eval
#   Downloading sed_eval-0.2.1.tar.gz (21 kB)
# Collecting pytorch-lightning>=1.6
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 60.5 MB/s
# Collecting spotty
#   Downloading spotty-1.3.3-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 80.7 MB/s
# Collecting dcase-util
#   Downloading dcase_util-0.2.19.tar.gz (2.1 MB)
#      |████████████████████████████████| 2.1 MB 52.9 MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from heareval) (7.1.2)
# Requirement already satisfied: intervaltree in /usr/local/lib/python3.7/dist-packages (from heareval) (2.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba==0.48->heareval) (57.4.0)
# Collecting llvmlite<0.32.0,>=0.31.0dev0
#   Downloading llvmlite-0.31.0-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
#      |████████████████████████████████| 20.2 MB 1.3 MB/s
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6->heareval) (3.17.3)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6->heareval) (2.8.0)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.0-py3-none-any.whl (418 kB)
#      |████████████████████████████████| 418 kB 60.7 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6->heareval) (4.2.0)
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 68.8 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6->heareval) (21.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 76.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6->heareval) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 72.4 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning>=1.6->heareval) (3.0.9)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1->pytorch-lightning>=1.6->heareval) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->heareval) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->heareval) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->heareval) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (1.35.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (1.46.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (1.0.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6->heareval) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6->heareval) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6->heareval) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6->heareval) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6->heareval) (3.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (3.3.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (0.5.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (1.14.1)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (14.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (1.6.3)
# Collecting tensorflow>=2.0
#   Downloading tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 6.2 kB/s
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 71.9 MB/s
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 24.7 MB/s
# Collecting tensorflow>=2.0
#   Downloading tensorflow-2.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 4.5 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.2%2Bzzzcolab20220523105045-cp37-cp37m-linux_x86_64.whl
#      - 668.6 MB 127.6 MB/s
#   Downloading tensorflow-2.8.2-cp37-cp37m-manylinux2010_x86_64.whl (497.9 MB)
#      |████████████████████████████████| 497.9 MB 16 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.1%2Bzzzcolab20220518083849-cp37-cp37m-linux_x86_64.whl
#      / 668.6 MB 145.0 MB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.1%2Bzzzcolab20220516111314-cp37-cp37m-linux_x86_64.whl
#      \ 668.6 MB 445 kB/s
#   Downloading tensorflow-2.8.1-cp37-cp37m-manylinux2010_x86_64.whl (497.9 MB)
#      |████████████████████████████████| 497.9 MB 18 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.0%2Bzzzcolab20220506162203-cp37-cp37m-linux_x86_64.whl
#      / 668.3 MB 429 kB/s
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 56.1 MB/s
# Collecting tensorflow>=2.0
#   Downloading tensorflow-2.8.0-cp37-cp37m-manylinux2010_x86_64.whl (497.5 MB)
#      |████████████████████████████████| 497.5 MB 28 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.7.3%2Bzzzcolab20220523111007-cp37-cp37m-linux_x86_64.whl
#      | 671.4 MB 268 kB/s
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 76.3 MB/s
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 54.9 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->heareval) (0.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.0->heareval) (1.5.2)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 5.1 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6->heareval) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 70.4 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 63.2 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6->heareval) (2.0.12)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from dcase-util->heareval) (3.2.2)
# Requirement already satisfied: librosa>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from dcase-util->heareval) (0.8.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from dcase-util->heareval) (0.16.0)
# Requirement already satisfied: pydot-ng>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from dcase-util->heareval) (2.0.0)
# Collecting validators>=0.12.0
#   Downloading validators-0.19.0.tar.gz (30 kB)
# Collecting python-magic>=0.4.13
#   Downloading python_magic-0.4.26-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.7.0->dcase-util->heareval) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.7.0->dcase-util->heareval) (4.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.7.0->dcase-util->heareval) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.7.0->dcase-util->heareval) (0.2.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->dcase-util->heareval) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->dcase-util->heareval) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->dcase-util->heareval) (2.8.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa>=0.7.0->dcase-util->heareval) (1.4.4)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->heareval) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->heareval) (2.21)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from intervaltree->heareval) (2.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->heareval) (2022.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->heareval) (1.3)
# Requirement already satisfied: google-cloud-storage>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotty->heareval) (1.18.1)
# Collecting boto3>=1.9.0
#   Downloading boto3-1.24.2-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 70.9 MB/s
# Collecting cfn-flip
#   Downloading cfn_flip-1.3.0-py3-none-any.whl (21 kB)
# Collecting schema
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.7/dist-packages (from spotty->heareval) (1.12.11)
# Collecting chevron
#   Downloading chevron-0.14.0-py3-none-any.whl (11 kB)
# Collecting botocore<1.28.0,>=1.27.2
#   Downloading botocore-1.27.2-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 59.3 MB/s
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 11.9 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 77.4 MB/s
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.7.8->spotty->heareval) (0.17.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.7.8->spotty->heareval) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.7.8->spotty->heareval) (0.0.4)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.7.8->spotty->heareval) (1.31.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.7.8->spotty->heareval) (1.56.2)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage>=1.15.0->spotty->heareval) (0.4.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage>=1.15.0->spotty->heareval) (1.0.3)
# Requirement already satisfied: contextlib2>=0.5.5 in /usr/local/lib/python3.7/dist-packages (from schema->spotty->heareval) (0.5.5)
# Building wheels for collected packages: dcase-util, validators, sed-eval
#   Building wheel for dcase-util (setup.py) ... done
#   Created wheel for dcase-util: filename=dcase_util-0.2.19-py3-none-any.whl size=2162500 sha256=e6262948910d4bb70b74c9c09a52b9e68fade34556b784420200e62348c8f44f
#   Stored in directory: /root/.cache/pip/wheels/38/a9/49/3dcce0c0b112670480e105a4a8e985e2ccddb7b77065b4aac2
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.19.0-py3-none-any.whl size=19553 sha256=912449e2c7f8f07375fe7f1252ee4f4f6688d83c8629d6e3a7464f44825a8a30
#   Stored in directory: /root/.cache/pip/wheels/fe/5d/69/ff53a908b9f14fb7730a58fdede0fac4cdc99ef3624ec76d05
#   Building wheel for sed-eval (setup.py) ... done
#   Created wheel for sed-eval: filename=sed_eval-0.2.1-py3-none-any.whl size=26124 sha256=f49b332664f995ceda9d9253de553ff3ecfe9e01c71c94583ddac6a18929347a
#   Stored in directory: /root/.cache/pip/wheels/96/19/00/a3ec89acfdbd2568185a1ae3020590e76ee73a47ac4ff83e84
# Successfully built dcase-util validators sed-eval
# Installing collected packages: urllib3, numpy, llvmlite, numba, multidict, jmespath, frozenlist, yarl, botocore, asynctest, async-timeout, aiosignal, validators, s3transfer, PyYAML, python-magic, fsspec, aiohttp, torchmetrics, tensorflow-estimator, schema, pyDeprecate, keras, gast, dcase-util, chevron, cfn-flip, boto3, torchinfo, tensorflow, spotty, sed-eval, pytorch-lightning, pynvml, heareval
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
#     Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 boto3-1.24.2 botocore-1.27.2 cfn-flip-1.3.0 chevron-0.14.0 dcase-util-0.2.19 frozenlist-1.3.0 fsspec-2022.5.0 gast-0.4.0 heareval-2021.1.2 jmespath-1.0.0 keras-2.7.0 llvmlite-0.31.0 multidict-6.0.2 numba-0.48.0 numpy-1.19.2 pyDeprecate-0.3.2 pynvml-11.4.1 python-magic-0.4.26 pytorch-lightning-1.6.4 s3transfer-0.6.0 schema-0.7.5 sed-eval-0.2.1 spotty-1.3.3 tensorflow-2.7.3+zzzcolab20220523111007 tensorflow-estimator-2.7.0 torchinfo-1.7.0 torchmetrics-0.9.0 urllib3-1.25.11 validators-0.19.0 yarl-1.7.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hearbaseline
#   Downloading hearbaseline-2021.1.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: tensorflow>=2.0 in /usr/local/lib/python3.7/dist-packages (from hearbaseline) (2.7.3+zzzcolab20220523111007)
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 34.0 MB/s
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from hearbaseline) (0.8.1)
# Requirement already satisfied: numba==0.48 in /usr/local/lib/python3.7/dist-packages (from hearbaseline) (0.48.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from hearbaseline) (1.0.2)
# Collecting speechbrain
#   Downloading speechbrain-0.5.11-py3-none-any.whl (408 kB)
#      |████████████████████████████████| 408 kB 70.8 MB/s
# Requirement already satisfied: numpy==1.19.2 in /usr/local/lib/python3.7/dist-packages (from hearbaseline) (1.19.2)
# Collecting torchopenl3
#   Downloading torchopenl3-1.0.0-py2.py3-none-any.whl (14 kB)
# Collecting torchcrepe
#   Downloading torchcrepe-0.0.16-py3-none-any.whl (72.3 MB)
#      |████████████████████████████████| 72.3 MB 5.2 kB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from hearbaseline) (1.11.0+cu113)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba==0.48->hearbaseline) (0.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba==0.48->hearbaseline) (57.4.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->hearbaseline) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->hearbaseline) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->hearbaseline) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (1.46.3)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (0.37.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (1.0.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (2.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (3.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (0.26.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (0.2.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (14.0.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (1.15.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (3.17.3)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (2.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (2.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0->hearbaseline) (4.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.0->hearbaseline) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.0->hearbaseline) (3.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa->hearbaseline) (21.3)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->hearbaseline) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->hearbaseline) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->hearbaseline) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->hearbaseline) (4.4.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa->hearbaseline) (0.10.3.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa->hearbaseline) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->hearbaseline) (1.4.4)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa->hearbaseline) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->hearbaseline) (2.21)
# Collecting hyperpyyaml
#   Downloading HyperPyYAML-1.0.1.tar.gz (14 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 54.3 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 7.7 MB/s
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (from speechbrain->hearbaseline) (0.11.0+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from speechbrain->hearbaseline) (4.64.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->speechbrain->hearbaseline) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->speechbrain->hearbaseline) (3.7.0)
# Collecting ruamel.yaml>=0.17.8
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 68.0 MB/s
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 61.3 MB/s
# Collecting librosa
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      |████████████████████████████████| 213 kB 42.3 MB/s
# Collecting nnAudio>=0.2.4
#   Downloading nnAudio-0.3.1-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.6 MB/s
# Collecting julius>=0.2.5
#   Downloading julius-0.2.6.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 8.5 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 58.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->hearbaseline) (2019.12.20)
# Building wheels for collected packages: hyperpyyaml, julius
#   Building wheel for hyperpyyaml (setup.py) ... done
#   Created wheel for hyperpyyaml: filename=HyperPyYAML-1.0.1-py3-none-any.whl size=15192 sha256=0c41165eabddce46f03a957753035cd44545c5b11951f3aaae0f388013fed5a6
#   Stored in directory: /root/.cache/pip/wheels/6c/87/65/266d722c3932f81f16332ce842e972be8421e3a9cd3771766b
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.6-py3-none-any.whl size=20965 sha256=3b9e9a35a69ae982607c90e62e23b1d67b98b5f8a82e4636cd03d1d55da9b1ba
#   Stored in directory: /root/.cache/pip/wheels/ad/6f/00/57039014814f8794b1f32aad93d1d387645d103afdda943caf
# Successfully built hyperpyyaml julius
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, tokenizers, sentencepiece, nnAudio, librosa, julius, hyperpyyaml, huggingface-hub, transformers, torchopenl3, torchcrepe, speechbrain, hearbaseline
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# Successfully installed hearbaseline-2021.1.0 huggingface-hub-0.7.0 hyperpyyaml-1.0.1 julius-0.2.6 librosa-0.9.1 nnAudio-0.3.1 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6 sentencepiece-0.1.96 speechbrain-0.5.11 tokenizers-0.12.1 torchcrepe-0.0.16 torchopenl3-1.0.0 transformers-4.19.2

# %% [markdown]
# ## 2. Download the Dataset
#
# We download the Mridingham Tonic dataset with samplerate 16000 as an example.

# %%
# !wget https://github.com/hearbenchmark/hear2021-sample-datasets/raw/main/hear2021-mridangam_tonic-v1.5-full-16000.tar.gz
# !tar -xzf hear2021-mridangam_tonic-v1.5-full-16000.tar.gz
# Out:
# --2022-06-03 21:05:18--  https://github.com/hearbenchmark/hear2021-sample-datasets/raw/main/hear2021-mridangam_tonic-v1.5-full-16000.tar.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hearbenchmark/hear2021-sample-datasets/main/hear2021-mridangam_tonic-v1.5-full-16000.tar.gz [following]
# --2022-06-03 21:05:18--  https://raw.githubusercontent.com/hearbenchmark/hear2021-sample-datasets/main/hear2021-mridangam_tonic-v1.5-full-16000.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62455362 (60M) [application/octet-stream]
# Saving to: ‘hear2021-mridangam_tonic-v1.5-full-16000.tar.gz’
#
# hear2021-mridangam_ 100%[===================>]  59.56M   256MB/s    in 0.2s
#
# 2022-06-03 21:05:19 (256 MB/s) - ‘hear2021-mridangam_tonic-v1.5-full-16000.tar.gz’ saved [62455362/62455362]

# %% [markdown]
# ## 3. Compute embeddings using Wav2Vec2

# %%
# !python3 -m heareval.embeddings.runner hearbaseline.wav2vec2 --tasks-dir ./tasks/
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/heareval/embeddings/runner.py:22: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2022-06-03 21:05:31.459094: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# embeddings
# Importing hearbaseline.wav2vec2
# Downloading: 100% 212/212 [00:00<00:00, 361kB/s]
# Downloading: 100% 1.73k/1.73k [00:00<00:00, 3.23MB/s]
# Downloading: 100% 1.18G/1.18G [00:21<00:00, 58.3MB/s]
# Some weights of the model checkpoint at facebook/wav2vec2-large-100k-voxpopuli were not used when initializing Wav2Vec2Model: ['quantizer.codevectors', 'project_q.bias', 'quantizer.weight_proj.bias', 'project_hid.bias', 'quantizer.weight_proj.weight', 'project_hid.weight', 'project_q.weight']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# speechbrain.lobes.models.huggingface_wav2vec - wav2vec 2.0 is frozen.
#   0% 0/1 [00:00<?, ?it/s]Getting embeddings for split: fold00
# Estimated batch size = 103
#
#   0% 0/14 [00:00<?, ?it/s]
#   7% 1/14 [00:01<00:17,  1.34s/it]
#  14% 2/14 [00:02<00:13,  1.12s/it]
#  21% 3/14 [00:03<00:11,  1.05s/it]
#  29% 4/14 [00:04<00:10,  1.01s/it]
#  36% 5/14 [00:05<00:08,  1.01it/s]
#  43% 6/14 [00:06<00:07,  1.02it/s]
#  50% 7/14 [00:07<00:06,  1.02it/s]
#  57% 8/14 [00:08<00:05,  1.02it/s]
#  64% 9/14 [00:09<00:04,  1.02it/s]
#  71% 10/14 [00:10<00:03,  1.02it/s]
#  79% 11/14 [00:11<00:02,  1.02it/s]
#  86% 12/14 [00:12<00:01,  1.02it/s]
#  93% 13/14 [00:12<00:00,  1.02it/s]
# 100% 14/14 [00:13<00:00,  1.04it/s]
#
#   0% 0/1396 [00:00<?, ?it/s]
#  27% 373/1396 [00:00<00:00, 3724.60it/s]
#  55% 761/1396 [00:00<00:00, 3813.03it/s]
# 100% 1396/1396 [00:00<00:00, 3818.99it/s]
#
#   0% 0/1396 [00:00<?, ?it/s]
#  21% 295/1396 [00:00<00:00, 2946.14it/s]
#  42% 590/1396 [00:00<00:00, 2926.23it/s]
#  63% 883/1396 [00:00<00:00, 2919.35it/s]
# 100% 1396/1396 [00:00<00:00, 2925.61it/s]
# Getting embeddings for split: fold01
# Estimated batch size = 103
#
#   0% 0/14 [00:00<?, ?it/s]
#   7% 1/14 [00:01<00:14,  1.10s/it]
#  14% 2/14 [00:02<00:12,  1.07s/it]
#  21% 3/14 [00:03<00:11,  1.07s/it]
#  29% 4/14 [00:04<00:10,  1.05s/it]
#  36% 5/14 [00:05<00:09,  1.05s/it]
#  43% 6/14 [00:06<00:08,  1.04s/it]
#  50% 7/14 [00:07<00:07,  1.03s/it]
#  57% 8/14 [00:08<00:06,  1.03s/it]
#  64% 9/14 [00:09<00:05,  1.02s/it]
#  71% 10/14 [00:10<00:04,  1.02s/it]
#  79% 11/14 [00:11<00:03,  1.02s/it]
#  86% 12/14 [00:12<00:02,  1.02s/it]
#  93% 13/14 [00:13<00:01,  1.02s/it]
# 100% 14/14 [00:13<00:00,  1.00it/s]
#
#   0% 0/1396 [00:00<?, ?it/s]
#  27% 370/1396 [00:00<00:00, 3698.35it/s]
#  54% 758/1396 [00:00<00:00, 3800.51it/s]
# 100% 1396/1396 [00:00<00:00, 3796.83it/s]
#
#   0% 0/1396 [00:00<?, ?it/s]
#  20% 275/1396 [00:00<00:00, 2747.55it/s]
#  40% 559/1396 [00:00<00:00, 2798.11it/s]
#  61% 851/1396 [00:00<00:00, 2852.39it/s]
# 100% 1396/1396 [00:00<00:00, 2869.97it/s]
# Getting embeddings for split: fold02
# Estimated batch size = 103
#
#   0% 0/14 [00:00<?, ?it/s]
#   7% 1/14 [00:01<00:13,  1.01s/it]
#  14% 2/14 [00:02<00:12,  1.01s/it]
#  21% 3/14 [00:03<00:11,  1.01s/it]
#  29% 4/14 [00:04<00:10,  1.01s/it]
#  36% 5/14 [00:05<00:09,  1.01s/it]
#  43% 6/14 [00:06<00:08,  1.02s/it]
#  50% 7/14 [00:07<00:07,  1.02s/it]
#  57% 8/14 [00:08<00:06,  1.02s/it]
#  64% 9/14 [00:09<00:05,  1.02s/it]
#  71% 10/14 [00:10<00:04,  1.03s/it]
#  79% 11/14 [00:11<00:03,  1.03s/it]
#  86% 12/14 [00:12<00:02,  1.04s/it]
#  93% 13/14 [00:13<00:01,  1.04s/it]
# 100% 14/14 [00:13<00:00,  1.01it/s]
#
#   0% 0/1395 [00:00<?, ?it/s]
#  27% 383/1395 [00:00<00:00, 3826.46it/s]
#  56% 777/1395 [00:00<00:00, 3888.96it/s]
# 100% 1395/1395 [00:00<00:00, 3849.71it/s]
#
#   0% 0/1395 [00:00<?, ?it/s]
#  21% 294/1395 [00:00<00:00, 2938.87it/s]
#  42% 588/1395 [00:00<00:00, 2917.24it/s]
#  63% 880/1395 [00:00<00:00, 2911.71it/s]
# 100% 1395/1395 [00:00<00:00, 2917.88it/s]
# Getting embeddings for split: fold03
# Estimated batch size = 103
#
#   0% 0/14 [00:00<?, ?it/s]
#   7% 1/14 [00:01<00:13,  1.05s/it]
#  14% 2/14 [00:02<00:12,  1.05s/it]
#  21% 3/14 [00:03<00:11,  1.05s/it]
#  29% 4/14 [00:04<00:10,  1.05s/it]
#  36% 5/14 [00:05<00:09,  1.05s/it]
#  43% 6/14 [00:06<00:08,  1.06s/it]
#  50% 7/14 [00:07<00:07,  1.06s/it]
#  57% 8/14 [00:08<00:06,  1.07s/it]
#  64% 9/14 [00:09<00:05,  1.07s/it]
#  71% 10/14 [00:10<00:04,  1.07s/it]
#  79% 11/14 [00:11<00:03,  1.08s/it]
#  86% 12/14 [00:12<00:02,  1.08s/it]
#  93% 13/14 [00:13<00:01,  1.07s/it]
# 100% 14/14 [00:14<00:00,  1.03s/it]
#
#   0% 0/1395 [00:00<?, ?it/s]
#  27% 380/1395 [00:00<00:00, 3799.05it/s]
#  55% 773/1395 [00:00<00:00, 3873.88it/s]
# 100% 1395/1395 [00:00<00:00, 3833.74it/s]
#
#   0% 0/1395 [00:00<?, ?it/s]
#  20% 285/1395 [00:00<00:00, 2847.44it/s]
#  41% 573/1395 [00:00<00:00, 2860.10it/s]
#  63% 872/1395 [00:00<00:00, 2918.81it/s]
# 100% 1395/1395 [00:00<00:00, 2851.71it/s]
# Getting embeddings for split: fold04
# Estimated batch size = 103
#
#   0% 0/14 [00:00<?, ?it/s]
#   7% 1/14 [00:01<00:15,  1.22s/it]
#  14% 2/14 [00:02<00:14,  1.18s/it]
#  21% 3/14 [00:03<00:12,  1.17s/it]
#  29% 4/14 [00:04<00:11,  1.16s/it]
#  36% 5/14 [00:05<00:10,  1.15s/it]
#  43% 6/14 [00:06<00:09,  1.15s/it]
#  50% 7/14 [00:08<00:07,  1.14s/it]
#  57% 8/14 [00:09<00:06,  1.13s/it]
#  64% 9/14 [00:10<00:05,  1.12s/it]
#  71% 10/14 [00:11<00:04,  1.11s/it]
#  79% 11/14 [00:12<00:03,  1.11s/it]
#  86% 12/14 [00:13<00:02,  1.11s/it]
#  93% 13/14 [00:14<00:01,  1.11s/it]
# 100% 14/14 [00:15<00:00,  1.09s/it]
#
#   0% 0/1395 [00:00<?, ?it/s]
#   0% 5/1395 [00:00<00:40, 34.07it/s]
#  27% 378/1395 [00:00<00:00, 1857.07it/s]
#  54% 757/1395 [00:00<00:00, 2652.08it/s]
# 100% 1395/1395 [00:00<00:00, 2707.67it/s]
#
#   0% 0/1395 [00:00<?, ?it/s]
#  20% 284/1395 [00:00<00:00, 2829.79it/s]
#  41% 578/1395 [00:00<00:00, 2893.04it/s]
#  62% 868/1395 [00:00<00:00, 2876.15it/s]
# 100% 1395/1395 [00:00<00:00, 2834.81it/s]
# ...computed embeddings in 75.6577308177948 sec (GPU max mem 4.63671875) for mridangam_tonic-v1.5-full using hearbaseline.wav2vec2 {}
# 100% 1/1 [01:15<00:00, 75.67s/it]

# %% [markdown]
# ## 4. Evaluate
# Train and predict with a shallow downstream classifier using the computed embeddings.

# %%
# Required for determinism
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8

# Train and evaluate classifier using hearbaseline embeddings
# !python3 -m heareval.predictions.runner embeddings/hearbaseline.wav2vec2/*
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 344: 100% 7/7 [00:00<00:00, 78.93it/s, loss=0.0451, v_num=8, val_loss=0.565, val_top1_acc=0.806, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.830]
# Epoch 347:   0% 0/7 [00:00<?, ?it/s, loss=0.045, v_num=8, val_loss=0.565, val_top1_acc=0.806, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.830]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 347: 100% 7/7 [00:00<00:00, 79.40it/s, loss=0.0444, v_num=8, val_loss=0.558, val_top1_acc=0.810, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.831]
# Epoch 350:   0% 0/7 [00:00<?, ?it/s, loss=0.0438, v_num=8, val_loss=0.558, val_top1_acc=0.810, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.831]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 350: 100% 7/7 [00:00<00:00, 51.18it/s, loss=0.0438, v_num=8, val_loss=0.570, val_top1_acc=0.801, val_d_prime=3.230, val_aucroc=0.958, val_mAP=0.830]
# Epoch 353:   0% 0/7 [00:00<?, ?it/s, loss=0.0439, v_num=8, val_loss=0.570, val_top1_acc=0.801, val_d_prime=3.230, val_aucroc=0.958, val_mAP=0.830]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 353: 100% 7/7 [00:00<00:00, 61.16it/s, loss=0.0443, v_num=8, val_loss=0.551, val_top1_acc=0.808, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.832]
# Epoch 356:   0% 0/7 [00:00<?, ?it/s, loss=0.0431, v_num=8, val_loss=0.551, val_top1_acc=0.808, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 356: 100% 7/7 [00:00<00:00, 66.36it/s, loss=0.0431, v_num=8, val_loss=0.565, val_top1_acc=0.807, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.831]
# Epoch 359:   0% 0/7 [00:00<?, ?it/s, loss=0.0429, v_num=8, val_loss=0.565, val_top1_acc=0.807, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.831]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 359: 100% 7/7 [00:00<00:00, 67.38it/s, loss=0.0427, v_num=8, val_loss=0.567, val_top1_acc=0.806, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.832]
# Epoch 362:   0% 0/7 [00:00<?, ?it/s, loss=0.0414, v_num=8, val_loss=0.567, val_top1_acc=0.806, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 362: 100% 7/7 [00:00<00:00, 59.81it/s, loss=0.0414, v_num=8, val_loss=0.568, val_top1_acc=0.805, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.831]
# Epoch 365:   0% 0/7 [00:00<?, ?it/s, loss=0.0409, v_num=8, val_loss=0.568, val_top1_acc=0.805, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.831]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 365: 100% 7/7 [00:00<00:00, 56.26it/s, loss=0.0407, v_num=8, val_loss=0.553, val_top1_acc=0.812, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Epoch 368:   0% 0/7 [00:00<?, ?it/s, loss=0.0395, v_num=8, val_loss=0.553, val_top1_acc=0.812, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 368: 100% 7/7 [00:00<00:00, 68.94it/s, loss=0.0396, v_num=8, val_loss=0.559, val_top1_acc=0.814, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.833]
# Epoch 371:   0% 0/7 [00:00<?, ?it/s, loss=0.0398, v_num=8, val_loss=0.559, val_top1_acc=0.814, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.833]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 371: 100% 7/7 [00:00<00:00, 56.16it/s, loss=0.0396, v_num=8, val_loss=0.570, val_top1_acc=0.809, val_d_prime=3.230, val_aucroc=0.958, val_mAP=0.832]
# Epoch 374:   0% 0/7 [00:00<?, ?it/s, loss=0.0391, v_num=8, val_loss=0.570, val_top1_acc=0.809, val_d_prime=3.230, val_aucroc=0.958, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 374: 100% 7/7 [00:00<00:00, 58.40it/s, loss=0.0389, v_num=8, val_loss=0.585, val_top1_acc=0.800, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.830]
# Epoch 377:   0% 0/7 [00:00<?, ?it/s, loss=0.0387, v_num=8, val_loss=0.585, val_top1_acc=0.800, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.830]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 377: 100% 7/7 [00:00<00:00, 61.88it/s, loss=0.0385, v_num=8, val_loss=0.557, val_top1_acc=0.814, val_d_prime=3.230, val_aucroc=0.960, val_mAP=0.834]
# Epoch 380:   0% 0/7 [00:00<?, ?it/s, loss=0.0378, v_num=8, val_loss=0.557, val_top1_acc=0.814, val_d_prime=3.230, val_aucroc=0.960, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 380: 100% 7/7 [00:00<00:00, 73.16it/s, loss=0.0379, v_num=8, val_loss=0.567, val_top1_acc=0.806, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.832]
# Epoch 383:   0% 0/7 [00:00<?, ?it/s, loss=0.0383, v_num=8, val_loss=0.567, val_top1_acc=0.806, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 383: 100% 7/7 [00:00<00:00, 23.99it/s, loss=0.0384, v_num=8, val_loss=0.588, val_top1_acc=0.806, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.833]
# Epoch 386:   0% 0/7 [00:00<?, ?it/s, loss=0.0379, v_num=8, val_loss=0.588, val_top1_acc=0.806, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.833]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 386: 100% 7/7 [00:00<00:00, 73.55it/s, loss=0.037, v_num=8, val_loss=0.567, val_top1_acc=0.809, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.832]
# Epoch 389:   0% 0/7 [00:00<?, ?it/s, loss=0.0365, v_num=8, val_loss=0.567, val_top1_acc=0.809, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 389: 100% 7/7 [00:00<00:00, 76.64it/s, loss=0.0358, v_num=8, val_loss=0.561, val_top1_acc=0.814, val_d_prime=3.240, val_aucroc=0.960, val_mAP=0.834]
# Epoch 392:   0% 0/7 [00:00<?, ?it/s, loss=0.0354, v_num=8, val_loss=0.561, val_top1_acc=0.814, val_d_prime=3.240, val_aucroc=0.960, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 392: 100% 7/7 [00:00<00:00, 56.07it/s, loss=0.0352, v_num=8, val_loss=0.567, val_top1_acc=0.816, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Epoch 395:   0% 0/7 [00:00<?, ?it/s, loss=0.0349, v_num=8, val_loss=0.567, val_top1_acc=0.816, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 395: 100% 7/7 [00:00<00:00, 63.05it/s, loss=0.0348, v_num=8, val_loss=0.565, val_top1_acc=0.811, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Epoch 398:   0% 0/7 [00:00<?, ?it/s, loss=0.0344, v_num=8, val_loss=0.565, val_top1_acc=0.811, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 398: 100% 7/7 [00:00<00:00, 75.67it/s, loss=0.0348, v_num=8, val_loss=0.581, val_top1_acc=0.806, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.832]
# Epoch 401:   0% 0/7 [00:00<?, ?it/s, loss=0.0347, v_num=8, val_loss=0.581, val_top1_acc=0.806, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 401: 100% 7/7 [00:00<00:00, 67.95it/s, loss=0.0349, v_num=8, val_loss=0.594, val_top1_acc=0.806, val_d_prime=3.230, val_aucroc=0.958, val_mAP=0.832]
# Epoch 404:   0% 0/7 [00:00<?, ?it/s, loss=0.0347, v_num=8, val_loss=0.594, val_top1_acc=0.806, val_d_prime=3.230, val_aucroc=0.958, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 404: 100% 7/7 [00:00<00:00, 75.44it/s, loss=0.0351, v_num=8, val_loss=0.581, val_top1_acc=0.811, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.832]
# Epoch 407:   0% 0/7 [00:00<?, ?it/s, loss=0.0343, v_num=8, val_loss=0.581, val_top1_acc=0.811, val_d_prime=3.220, val_aucroc=0.958, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 407: 100% 7/7 [00:00<00:00, 61.72it/s, loss=0.0346, v_num=8, val_loss=0.583, val_top1_acc=0.811, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.834]
# Epoch 410:   0% 0/7 [00:00<?, ?it/s, loss=0.035, v_num=8, val_loss=0.583, val_top1_acc=0.811, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 410: 100% 7/7 [00:00<00:00, 64.69it/s, loss=0.0351, v_num=8, val_loss=0.576, val_top1_acc=0.812, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.833]
# Epoch 413:   0% 0/7 [00:00<?, ?it/s, loss=0.0353, v_num=8, val_loss=0.576, val_top1_acc=0.812, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.833]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 413: 100% 7/7 [00:00<00:00, 79.18it/s, loss=0.0341, v_num=8, val_loss=0.601, val_top1_acc=0.801, val_d_prime=3.220, val_aucroc=0.959, val_mAP=0.832]
# Epoch 416:   0% 0/7 [00:00<?, ?it/s, loss=0.0332, v_num=8, val_loss=0.601, val_top1_acc=0.801, val_d_prime=3.220, val_aucroc=0.959, val_mAP=0.832]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 416: 100% 7/7 [00:00<00:00, 68.09it/s, loss=0.0329, v_num=8, val_loss=0.586, val_top1_acc=0.811, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.834]
# Epoch 419:   0% 0/7 [00:00<?, ?it/s, loss=0.032, v_num=8, val_loss=0.586, val_top1_acc=0.811, val_d_prime=3.230, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 419: 100% 7/7 [00:00<00:00, 52.16it/s, loss=0.0317, v_num=8, val_loss=0.589, val_top1_acc=0.809, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Epoch 422:   0% 0/7 [00:00<?, ?it/s, loss=0.0311, v_num=8, val_loss=0.589, val_top1_acc=0.809, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 422: 100% 7/7 [00:00<00:00, 80.42it/s, loss=0.0307, v_num=8, val_loss=0.612, val_top1_acc=0.797, val_d_prime=3.210, val_aucroc=0.958, val_mAP=0.831]
# Epoch 425:   0% 0/7 [00:00<?, ?it/s, loss=0.0307, v_num=8, val_loss=0.612, val_top1_acc=0.797, val_d_prime=3.210, val_aucroc=0.958, val_mAP=0.831]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 425: 100% 7/7 [00:00<00:00, 68.66it/s, loss=0.0309, v_num=8, val_loss=0.586, val_top1_acc=0.809, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.835]
# Epoch 428:   0% 0/7 [00:00<?, ?it/s, loss=0.0307, v_num=8, val_loss=0.586, val_top1_acc=0.809, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.835]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 428: 100% 7/7 [00:00<00:00, 80.06it/s, loss=0.0303, v_num=8, val_loss=0.571, val_top1_acc=0.811, val_d_prime=3.250, val_aucroc=0.960, val_mAP=0.836]
# Epoch 431:   0% 0/7 [00:00<?, ?it/s, loss=0.03, v_num=8, val_loss=0.571, val_top1_acc=0.811, val_d_prime=3.250, val_aucroc=0.960, val_mAP=0.836]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 431: 100% 7/7 [00:00<00:00, 57.98it/s, loss=0.0298, v_num=8, val_loss=0.591, val_top1_acc=0.806, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.834]
# Epoch 434:   0% 0/7 [00:00<?, ?it/s, loss=0.0297, v_num=8, val_loss=0.591, val_top1_acc=0.806, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 434: 100% 7/7 [00:00<00:00, 70.44it/s, loss=0.0296, v_num=8, val_loss=0.595, val_top1_acc=0.809, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.833]
# Epoch 437:   0% 0/7 [00:00<?, ?it/s, loss=0.029, v_num=8, val_loss=0.595, val_top1_acc=0.809, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.833]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 437: 100% 7/7 [00:00<00:00, 80.10it/s, loss=0.0289, v_num=8, val_loss=0.592, val_top1_acc=0.807, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Epoch 440:   0% 0/7 [00:00<?, ?it/s, loss=0.0284, v_num=8, val_loss=0.592, val_top1_acc=0.807, val_d_prime=3.240, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 440: 100% 7/7 [00:00<00:00, 60.08it/s, loss=0.0283, v_num=8, val_loss=0.575, val_top1_acc=0.814, val_d_prime=3.250, val_aucroc=0.960, val_mAP=0.836]
# Epoch 443:   0% 0/7 [00:00<?, ?it/s, loss=0.028, v_num=8, val_loss=0.575, val_top1_acc=0.814, val_d_prime=3.250, val_aucroc=0.960, val_mAP=0.836]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 443: 100% 7/7 [00:00<00:00, 53.81it/s, loss=0.0282, v_num=8, val_loss=0.578, val_top1_acc=0.812, val_d_prime=3.250, val_aucroc=0.960, val_mAP=0.836]
# Epoch 446:   0% 0/7 [00:00<?, ?it/s, loss=0.0279, v_num=8, val_loss=0.578, val_top1_acc=0.812, val_d_prime=3.250, val_aucroc=0.960, val_mAP=0.836]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 446: 100% 7/7 [00:00<00:00, 70.28it/s, loss=0.028, v_num=8, val_loss=0.591, val_top1_acc=0.811, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.834]
# Epoch 449:   0% 0/7 [00:00<?, ?it/s, loss=0.0282, v_num=8, val_loss=0.591, val_top1_acc=0.811, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 449: 100% 7/7 [00:00<00:00, 54.82it/s, loss=0.0278, v_num=8, val_loss=0.595, val_top1_acc=0.808, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.834]
# Epoch 452:   0% 0/7 [00:00<?, ?it/s, loss=0.0269, v_num=8, val_loss=0.595, val_top1_acc=0.808, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.834]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/heareval/predictions/task_predictions.py:193: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.activation(x)
#
# Epoch 452: 100% 7/7 [00:00<00:00, 58.67it/s, loss=0.0271, v_num=8, val_loss=0.601, val_top1_acc=0.810, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.835]
# Epoch 452: 100% 7/7 [00:00<00:00, 55.76it/s, loss=0.0271, v_num=8, val_loss=0.601, val_top1_acc=0.810, val_d_prime=3.250, val_aucroc=0.959, val_mAP=0.835]
# FIT Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                                                              	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                                                               	|  -              	|  129115         	|  37.259         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                                                                  	|  0.08025        	|  453            	|  36.353         	|  97.568         	|
# |  run_training_batch                                                                                                                                                                                                  	|  0.0038716      	|  2265           	|  8.7691         	|  23.535         	|
# |  [LightningModule]ScenePredictionModel.optimizer_step                                                                                                                                                                	|  0.003553       	|  2265           	|  8.0476         	|  21.599         	|
# |  [LightningModule]ScenePredictionModel.validation_epoch_end                                                                                                                                                          	|  0.031854       	|  151            	|  4.8099         	|  12.909         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                                                                        	|  0.0015094      	|  2265           	|  3.4188         	|  9.1758         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                                                                             	|  0.00086097     	|  2265           	|  1.9501         	|  5.2339         	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_validation_end                 	|  0.012299       	|  151            	|  1.8572         	|  4.9845         	|
# |  on_train_batch_end                                                                                                                                                                                                  	|  0.00031309     	|  2265           	|  0.70915        	|  1.9033         	|
# |  on_train_batch_start                                                                                                                                                                                                	|  0.00018483     	|  2265           	|  0.41863        	|  1.1236         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                                                                      	|  0.00010058     	|  2567           	|  0.25819        	|  0.69296        	|
# |  [LightningModule]ScenePredictionModel.optimizer_zero_grad                                                                                                                                                           	|  0.000109       	|  2265           	|  0.24688        	|  0.66261        	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                                                                      	|  0.00066784     	|  302            	|  0.20169        	|  0.54131        	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                                                                        	|  0.00036245     	|  453            	|  0.16419        	|  0.44067        	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                                                                      	|  0.00025083     	|  453            	|  0.11363        	|  0.30497        	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                                                                         	|  0.00059906     	|  151            	|  0.090458       	|  0.24278        	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_validation_end                                                                                                                                 	|  0.00047375     	|  151            	|  0.071536       	|  0.192          	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                                                                   	|  0.00017963     	|  302            	|  0.054247       	|  0.14559        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                                                                       	|  0.00028195     	|  151            	|  0.042574       	|  0.11426        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                                                                 	|  0.00013777     	|  302            	|  0.041607       	|  0.11167        	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_after_backward                                                                                                                                 	|  6.9613e-06     	|  2265           	|  0.015767       	|  0.042318       	|
# |  [LightningModule]ScenePredictionModel.on_validation_model_train                                                                                                                                                     	|  8.3876e-05     	|  151            	|  0.012665       	|  0.033992       	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_before_zero_grad                                                                                                                               	|  5.5301e-06     	|  2265           	|  0.012526       	|  0.033617       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_train_epoch_end                	|  2.6662e-05     	|  453            	|  0.012078       	|  0.032416       	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_batch_start                                                                                                                                    	|  5.2053e-06     	|  2265           	|  0.01179        	|  0.031643       	|
# |  [LightningModule]ScenePredictionModel.on_validation_model_eval                                                                                                                                                      	|  7.6136e-05     	|  151            	|  0.011497       	|  0.030855       	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_batch_end                                                                                                                                      	|  4.6392e-06     	|  2265           	|  0.010508       	|  0.028202       	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                                                                         	|  4.3358e-06     	|  2265           	|  0.0098205      	|  0.026357       	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_before_optimizer_step                                                                                                                          	|  4.2763e-06     	|  2265           	|  0.0096857      	|  0.025995       	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_before_backward                                                                                                                                	|  4.271e-06      	|  2265           	|  0.0096739      	|  0.025964       	|
# |  [Callback]TQDMProgressBar.on_batch_start                                                                                                                                                                            	|  3.9924e-06     	|  2265           	|  0.0090428      	|  0.02427        	|
# |  [Callback]GradientAccumulationScheduler.on_after_backward                                                                                                                                                           	|  3.9917e-06     	|  2265           	|  0.0090413      	|  0.024266       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                                                                       	|  3.9335e-06     	|  2265           	|  0.0089094      	|  0.023912       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                                                                            	|  3.9065e-06     	|  2265           	|  0.0088481      	|  0.023747       	|
# |  [Callback]GradientAccumulationScheduler.on_before_optimizer_step                                                                                                                                                    	|  3.8711e-06     	|  2265           	|  0.0087679      	|  0.023532       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_after_backward                 	|  3.8272e-06     	|  2265           	|  0.0086686      	|  0.023266       	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                                                                  	|  3.7877e-06     	|  2265           	|  0.008579       	|  0.023025       	|
# |  [Callback]ModelSummary.on_batch_start                                                                                                                                                                               	|  3.7613e-06     	|  2265           	|  0.0085193      	|  0.022865       	|
# |  [Callback]GradientAccumulationScheduler.on_before_backward                                                                                                                                                          	|  3.7538e-06     	|  2265           	|  0.0085023      	|  0.022819       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_before_optimizer_step          	|  3.7194e-06     	|  2265           	|  0.0084243      	|  0.02261        	|
# |  [Callback]TQDMProgressBar.on_batch_end                                                                                                                                                                              	|  3.7159e-06     	|  2265           	|  0.0084165      	|  0.022589       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_batch_start                    	|  3.711e-06      	|  2265           	|  0.0084055      	|  0.022559       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_before_zero_grad               	|  3.701e-06      	|  2265           	|  0.0083828      	|  0.022498       	|
# |  [Callback]ModelSummary.on_batch_end                                                                                                                                                                                 	|  3.6895e-06     	|  2265           	|  0.0083567      	|  0.022429       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                                                                        	|  3.6812e-06     	|  2265           	|  0.0083379      	|  0.022378       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_batch_end                      	|  3.6796e-06     	|  2265           	|  0.0083343      	|  0.022368       	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                                                                     	|  3.6736e-06     	|  2265           	|  0.0083208      	|  0.022332       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                                                                           	|  3.5814e-06     	|  2265           	|  0.0081119      	|  0.021771       	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                                                                          	|  3.5612e-06     	|  2265           	|  0.008066       	|  0.021648       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_before_backward                	|  3.5247e-06     	|  2265           	|  0.0079835      	|  0.021427       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_start                                                                                                                                                              	|  3.5081e-06     	|  2265           	|  0.0079459      	|  0.021326       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_end                                                                                                                                                                	|  3.4592e-06     	|  2265           	|  0.0078351      	|  0.021028       	|
# |  [Callback]GradientAccumulationScheduler.on_before_zero_grad                                                                                                                                                         	|  3.4344e-06     	|  2265           	|  0.0077789      	|  0.020878       	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                                                                           	|  1.1845e-05     	|  453            	|  0.0053656      	|  0.014401       	|
# |  [LightningModule]ScenePredictionModel.training_step_end                                                                                                                                                             	|  2.0733e-06     	|  2265           	|  0.004696       	|  0.012604       	|
# |  [LightningModule]ScenePredictionModel.on_train_batch_end                                                                                                                                                            	|  1.9694e-06     	|  2265           	|  0.0044607      	|  0.011972       	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                                                                         	|  9.5696e-06     	|  453            	|  0.004335       	|  0.011635       	|
# |  [LightningModule]ScenePredictionModel.on_after_backward                                                                                                                                                             	|  1.8986e-06     	|  2265           	|  0.0043004      	|  0.011542       	|
# |  [LightningModule]ScenePredictionModel.on_train_batch_start                                                                                                                                                          	|  1.8762e-06     	|  2265           	|  0.0042495      	|  0.011405       	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_start                                                                                                                                                        	|  9.1898e-06     	|  453            	|  0.004163       	|  0.011173       	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                                                                 	|  1.5273e-06     	|  2265           	|  0.0034593      	|  0.0092844      	|
# |  [LightningModule]ScenePredictionModel.on_before_zero_grad                                                                                                                                                           	|  1.5197e-06     	|  2265           	|  0.0034422      	|  0.0092384      	|
# |  [Strategy]SingleDeviceStrategy.training_step_end                                                                                                                                                                    	|  1.5144e-06     	|  2265           	|  0.0034301      	|  0.0092061      	|
# |  [LightningModule]ScenePredictionModel.on_before_backward                                                                                                                                                            	|  1.4164e-06     	|  2265           	|  0.0032082      	|  0.0086103      	|
# |  [LightningModule]ScenePredictionModel.on_before_optimizer_step                                                                                                                                                      	|  1.4131e-06     	|  2265           	|  0.0032007      	|  0.0085904      	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_epoch_start                                                                                                                                    	|  4.4802e-06     	|  604            	|  0.002706       	|  0.0072627      	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_epoch_end                                                                                                                                      	|  4.0706e-06     	|  604            	|  0.0024587      	|  0.0065988      	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                                                                      	|  8.0803e-06     	|  302            	|  0.0024402      	|  0.0065494      	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_train_epoch_end                                                                                                                                	|  5.3053e-06     	|  453            	|  0.0024033      	|  0.0064503      	|
# |  [Callback]TQDMProgressBar.on_epoch_start                                                                                                                                                                            	|  3.8064e-06     	|  604            	|  0.0022991      	|  0.0061705      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_epoch_start                    	|  3.6982e-06     	|  604            	|  0.0022337      	|  0.005995       	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                                                                    	|  7.2857e-06     	|  302            	|  0.0022003      	|  0.0059053      	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_start                                                                                                                                                              	|  3.5697e-06     	|  604            	|  0.0021561      	|  0.0057867      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_epoch_end                      	|  3.5533e-06     	|  604            	|  0.0021462      	|  0.0057601      	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_end                                                                                                                                                                	|  3.5452e-06     	|  604            	|  0.0021413      	|  0.005747       	|
# |  [Callback]ModelSummary.on_epoch_start                                                                                                                                                                               	|  3.5381e-06     	|  604            	|  0.002137       	|  0.0057354      	|
# |  [Callback]TQDMProgressBar.on_epoch_end                                                                                                                                                                              	|  3.5358e-06     	|  604            	|  0.0021356      	|  0.0057319      	|
# ...
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_pretrain_routine_end            	|  4.559e-06      	|  1              	|  4.559e-06      	|  2.2578e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_test_epoch_end                  	|  4.521e-06      	|  1              	|  4.521e-06      	|  2.239e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_fit_end                         	|  4.44e-06       	|  1              	|  4.44e-06       	|  2.1988e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_end                                                                                                                                                      	|  4.401e-06      	|  1              	|  4.401e-06      	|  2.1795e-05     	|
# |  [Callback]ModelSummary.on_pretrain_routine_end                                                                                                                                                                       	|  4.395e-06      	|  1              	|  4.395e-06      	|  2.1766e-05     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_end                                                                                                                                                                    	|  4.265e-06      	|  1              	|  4.265e-06      	|  2.1122e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.on_before_accelerator_backend_setup 	|  4.233e-06      	|  1              	|  4.233e-06      	|  2.0963e-05     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                                                                               	|  4.152e-06      	|  1              	|  4.152e-06      	|  2.0562e-05     	|
# |  [LightningModule]ScenePredictionModel.on_test_batch_start                                                                                                                                                            	|  2.0375e-06     	|  2              	|  4.075e-06      	|  2.0181e-05     	|
# |  [LightningModule]ScenePredictionModel.on_load_checkpoint                                                                                                                                                             	|  4.024e-06      	|  1              	|  4.024e-06      	|  1.9928e-05     	|
# |  [LightningModule]ScenePredictionModel.setup                                                                                                                                                                          	|  1.9995e-06     	|  2              	|  3.999e-06      	|  1.9804e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_train_end                                                                                                                                       	|  3.965e-06      	|  1              	|  3.965e-06      	|  1.9636e-05     	|
# |  [LightningModule]ScenePredictionModel.on_val_dataloader                                                                                                                                                              	|  3.827e-06      	|  1              	|  3.827e-06      	|  1.8953e-05     	|
# |  [LightningModule]ScenePredictionModel.on_test_dataloader                                                                                                                                                             	|  3.699e-06      	|  1              	|  3.699e-06      	|  1.8319e-05     	|
# |  [LightningModule]ScenePredictionModel.on_test_batch_end                                                                                                                                                              	|  1.7645e-06     	|  2              	|  3.529e-06      	|  1.7477e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_test_start                                                                                                                                                                	|  3.436e-06      	|  1              	|  3.436e-06      	|  1.7016e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_top1_acc', 'mode': 'max'}.on_test_epoch_start                                                                                                                                	|  3.333e-06      	|  1              	|  3.333e-06      	|  1.6506e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_test_epoch_start                	|  3.054e-06      	|  1              	|  3.054e-06      	|  1.5124e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_test_start                      	|  3.054e-06      	|  1              	|  3.054e-06      	|  1.5124e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_train_end                       	|  3.026e-06      	|  1              	|  3.026e-06      	|  1.4986e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_end                                                                                                                                                                 	|  3.026e-06      	|  1              	|  3.026e-06      	|  1.4986e-05     	|
# |  [Strategy]SingleDeviceStrategy.test_step_end                                                                                                                                                                         	|  1.511e-06      	|  2              	|  3.022e-06      	|  1.4966e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_top1_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': False}.on_before_accelerator_backend_setup	|  2.973e-06      	|  1              	|  2.973e-06      	|  1.4723e-05     	|
# |  [LightningModule]ScenePredictionModel.on_train_dataloader                                                                                                                                                            	|  2.8e-06        	|  1              	|  2.8e-06        	|  1.3867e-05     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                                                                           	|  2.739e-06      	|  1              	|  2.739e-06      	|  1.3564e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_test_epoch_start                                                                                                                                                          	|  2.703e-06      	|  1              	|  2.703e-06      	|  1.3386e-05     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                                                                        	|  2.674e-06      	|  1              	|  2.674e-06      	|  1.3243e-05     	|
# |  [LightningModule]ScenePredictionModel.on_train_start                                                                                                                                                                 	|  2.462e-06      	|  1              	|  2.462e-06      	|  1.2193e-05     	|
# |  [LightningModule]ScenePredictionModel.on_test_end                                                                                                                                                                    	|  2.252e-06      	|  1              	|  2.252e-06      	|  1.1153e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                                                                        	|  2.247e-06      	|  1              	|  2.247e-06      	|  1.1128e-05     	|
# |  [LightningModule]ScenePredictionModel.on_fit_start                                                                                                                                                                   	|  2.147e-06      	|  1              	|  2.147e-06      	|  1.0633e-05     	|
# |  [LightningModule]ScenePredictionModel.on_fit_end                                                                                                                                                                     	|  2.055e-06      	|  1              	|  2.055e-06      	|  1.0177e-05     	|
# |  [LightningModule]ScenePredictionModel.on_test_epoch_end                                                                                                                                                              	|  1.99e-06       	|  1              	|  1.99e-06       	|  9.8551e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                                                                           	|  1.946e-06      	|  1              	|  1.946e-06      	|  9.6372e-06     	|
# |  [LightningModule]ScenePredictionModel.on_pretrain_routine_end                                                                                                                                                        	|  1.879e-06      	|  1              	|  1.879e-06      	|  9.3054e-06     	|
# |  [LightningModule]ScenePredictionModel.on_pretrain_routine_start                                                                                                                                                      	|  1.866e-06      	|  1              	|  1.866e-06      	|  9.2411e-06     	|
# |  [LightningModule]ScenePredictionModel.on_train_end                                                                                                                                                                   	|  1.484e-06      	|  1              	|  1.484e-06      	|  7.3493e-06     	|
# |  [LightningModule]ScenePredictionModel.on_test_start                                                                                                                                                                  	|  1.479e-06      	|  1              	|  1.479e-06      	|  7.3245e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                                                                         	|  1.321e-06      	|  1              	|  1.321e-06      	|  6.542e-06      	|
# |  [LightningModule]ScenePredictionModel.on_test_epoch_start                                                                                                                                                            	|  1.318e-06      	|  1              	|  1.318e-06      	|  6.5272e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                                                                          	|  1.245e-06      	|  1              	|  1.245e-06      	|  6.1657e-06     	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# predict - mridangam_stroke - 2022-06-03 21:10:54,435 - 435 - Final Test Results: {"fold00": {"test_loss": 0.48911142349243164, "test_score": 0.8202005624771118, "test_top1_acc": 0.8202005624771118, "test_d_prime": 3.0656446952202114, "test_aucroc": 0.9667379178924649, "test_mAP": 0.8648800803555511, "validation_score": 0.8388252258300781, "epoch": 104, "time_in_min": 0.28741658131281533}, "fold01": {"test_loss": 0.5804157257080078, "test_score": 0.8502865433692932, "test_top1_acc": 0.8502865433692932, "test_d_prime": 3.4191566852319224, "test_aucroc": 0.9709770413252347, "test_mAP": 0.8939131893403549, "validation_score": 0.8157706260681152, "epoch": 392, "time_in_min": 0.6220560510953267}, "fold02": {"test_loss": 0.5754764080047607, "test_score": 0.8035842180252075, "test_top1_acc": 0.8035842180252075, "test_d_prime": 3.180630890263927, "test_aucroc": 0.9591241195762334, "test_mAP": 0.8422802671924309, "validation_score": 0.8458781242370605, "epoch": 344, "time_in_min": 0.5587012489636739}, "fold03": {"test_loss": 0.4557825028896332, "test_score": 0.8451613187789917, "test_top1_acc": 0.8451613187789917, "test_d_prime": 3.476533598795452, "test_aucroc": 0.9735389632829503, "test_mAP": 0.8980638408963632, "validation_score": 0.8365591168403625, "epoch": 293, "time_in_min": 0.48952928781509397}, "fold04": {"test_loss": 0.5104941725730896, "test_score": 0.8258064389228821, "test_top1_acc": 0.8258064389228821, "test_d_prime": 3.154527975746111, "test_aucroc": 0.9675760111946247, "test_mAP": 0.8840364782336843, "validation_score": 0.8130372762680054, "epoch": 158, "time_in_min": 0.3118036468823751}, "aggregated_scores": {"test_loss_mean": 0.5222560465335846, "test_loss_std": 0.05447612981155485, "test_score_mean": 0.8290078163146972, "test_score_std": 0.01902561269892375, "test_top1_acc_mean": 0.8290078163146972, "test_top1_acc_std": 0.01902561269892375, "test_d_prime_mean": 3.2592987690515245, "test_d_prime_std": 0.1784747735771514, "test_aucroc_mean": 0.9675908106543016, "test_aucroc_std": 0.005460301748738511, "test_mAP_mean": 0.8766347712036768, "test_mAP_std": 0.0230810459628224, "validation_score_mean": 0.8300140738487244, "validation_score_std": 0.014690384121085987, "epoch_mean": 258.2, "epoch_std": 122.77296119260137, "time_in_min_mean": 0.453901363213857, "time_in_min_std": 0.1486920540179773}, "hparams": {"batch_size": 1024, "check_val_every_n_epoch": 3, "dropout": 0.1, "embedding_norm": "<class 'torch.nn.modules.linear.Identity'>", "hidden_dim": 1024, "hidden_layers": 1, "hidden_norm": "<class 'torch.nn.modules.batchnorm.BatchNorm1d'>", "initialization": "<function xavier_normal_ at 0x7fc4a4e26e60>", "lr": 0.0001, "max_epochs": 500, "norm_after_activation": false, "optim": "<class 'torch.optim.adam.Adam'>", "patience": 20}, "postprocessing": [], "score_mode": "max", "embedding_path": "embeddings/hearbaseline.wav2vec2/mridangam_tonic-v1.5-full"}
# predict - mridangam_stroke - 2022-06-03 21:10:54,441 - 441 - DONE took 200.98609924316406 seconds to complete task_predictions(embedding_path=embeddings/hearbaseline.wav2vec2/mridangam_tonic-v1.5-full, embedding_size=1024, grid_points=8, gpus=[0], gpu_max_mem_used=1.44140625, gpu_device_name=Tesla T4, in_memory=True, deterministic=True, grid=default)
# 100% 1/1 [03:20<00:00, 200.99s/it]

# %% [markdown]
# ## Results

# %%
import json
results = json.load(open("embeddings/hearbaseline.wav2vec2/mridangam_tonic-v1.5-full/test.predicted-scores.json"))
results["aggregated_scores"]
# Out:
# {'epoch_mean': 258.2,
#  'epoch_std': 122.77296119260137,
#  'test_aucroc_mean': 0.9675908106543016,
#  'test_aucroc_std': 0.005460301748738511,
#  'test_d_prime_mean': 3.2592987690515245,
#  'test_d_prime_std': 0.1784747735771514,
#  'test_loss_mean': 0.5222560465335846,
#  'test_loss_std': 0.05447612981155485,
#  'test_mAP_mean': 0.8766347712036768,
#  'test_mAP_std': 0.0230810459628224,
#  'test_score_mean': 0.8290078163146972,
#  'test_score_std': 0.01902561269892375,
#  'test_top1_acc_mean': 0.8290078163146972,
#  'test_top1_acc_std': 0.01902561269892375,
#  'time_in_min_mean': 0.453901363213857,
#  'time_in_min_std': 0.1486920540179773,
#  'validation_score_mean': 0.8300140738487244,
#  'validation_score_std': 0.014690384121085987}

# %%
results["aggregated_scores"]['test_score_mean']
# Out:
# 0.8290078163146972
